# %% [markdown]
# # 3.1 Histogram Equalization (HE)
#
# ## Objective
# To improve the global contrast of an image using Histogram Equalization.

# %%
import cv2
import matplotlib.pyplot as plt

# ==========================================
# 1. Read Image
# ==========================================

image = cv2.imread('/content/image.png')

if image is None:
    print("Error: Image not found!")

else:
    # Convert to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Histogram Equalization
    equalized = cv2.equalizeHist(gray)

    # ==========================================
    # 2. Display Images and Graphs
    # ==========================================

    plt.figure(figsize=(15, 10))

    # ------------------------------------------
    # Original Image
    # ------------------------------------------

    plt.subplot(2, 3, 1)
    plt.imshow(gray, cmap='gray')
    plt.title("Original Image")
    plt.axis("off")

    # ------------------------------------------
    # Input Intensity Histogram
    # ------------------------------------------

    plt.subplot(2, 3, 2)
    plt.hist(gray.ravel(), bins=256, range=[0, 256])
    plt.title("Input Intensity")
    plt.xlabel("Intensity")
    plt.ylabel("Number of Pixels")

    # ------------------------------------------
    # Equalized Image
    # ------------------------------------------

    plt.subplot(2, 3, 3)
    plt.imshow(equalized, cmap='gray')
    plt.title("Histogram Equalized Image")
    plt.axis("off")

    # ------------------------------------------
    # Original Image Histogram
    # ------------------------------------------

    plt.subplot(2, 3, 4)
    plt.hist(gray.ravel(), bins=256, range=[0, 256])
    plt.title("Original Intensity Histogram")
    plt.xlabel("Intensity")
    plt.ylabel("Frequency")

    # ------------------------------------------
    # Output Intensity Histogram
    # ------------------------------------------

    plt.subplot(2, 3, 5)
    plt.hist(equalized.ravel(), bins=256, range=[0, 256])
    plt.title("Output Intensity")
    plt.xlabel("Intensity")
    plt.ylabel("Number of Pixels")

    # ------------------------------------------
    # Equalized Histogram
    # ------------------------------------------

    plt.subplot(2, 3, 6)
    plt.hist(equalized.ravel(), bins=256, range=[0, 256])
    plt.title("Equalized Intensity Histogram")
    plt.xlabel("Intensity")
    plt.ylabel("Frequency")

    plt.tight_layout()
    plt.show()
